# %%
from sympy import sympify, symbols, Eq
from random import randint
import sympy as sp
import matplotlib.pyplot as plt
from io import BytesIO
from matplotlib.backends.backend_pdf import PdfPages

# Configure matplotlib to use LaTeX
plt.rcParams["text.usetex"] = True

def save_random_points_and_slope_to_pdf(x1, y1, x2, y2, slope, file_name):
    fig, ax = plt.subplots()

    # Set the title
    ax.set_title("Randomized 2 Points for Slope")

    # Display the points and slope as equations
    ax.text(0.5, 0.6, "Point 1: ({}, {})".format(x1, y1), fontsize=12, ha='center', va='center', transform=ax.transAxes)
    ax.text(0.5, 0.5, "Point 2: ({}, {})".format(x2, y2), fontsize=12, ha='center', va='center', transform=ax.transAxes)
    ax.text(0.5, 0.4, r"$m = \frac{" + str(y2 - y1) + "}{" + str(x2 - x1) + "}$", fontsize=12, ha='center', va='center', transform=ax.transAxes)

    # Hide the axis
    ax.set_xticks([])
    ax.set_yticks([])

    # Save the figure to a PDF
    with PdfPages(file_name) as pdf:
        pdf.savefig(fig, bbox_inches='tight')

    plt.close(fig)

x1, x2, y1, y2, m = symbols('x1 x2 y1 y2 m')

for i in range(10):
    x1 = sympify(randint(-10, 10))
    x2 = sympify(randint(-10, 10))
    y1 = sympify(randint(-10, 10))
    y2 = sympify(randint(-10, 10))

    slope = (y2 - y1)/(x2 - x1)

    # Save the randomized points and slope to a PDF
    file_name = "random_points_slope_{}.pdf".format(i)
    save_random_points_and_slope_to_pdf(x1, y1, x2, y2, slope, file_name)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /usr/lib/python3/dist-packages/matplotlib/texmanager.py in _run_checked_subprocess(self, command, tex, cwd)
#     232         try:
# --> 233             report = subprocess.check_output(
#     234                 command, cwd=cwd if cwd is not None else self.texcache,
#
# /usr/lib/python3.10/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     419
# --> 420     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     421                **kwargs).stdout
#
# /usr/lib/python3.10/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     500
# --> 501     with Popen(*popenargs, **kwargs) as process:
#     502         try:
#
# ...

# %%
# INPUT 2 POINTS TO FIND SLOPE

from sympy import sympify, symbols
from random import randint
import sympy as sp

x1, x2, y1, y2 = symbols('x1 x2 y1 y2')


x1 = sympify(input('Enter the x1 coordinate: '))
y1 = sympify(input('Enter the y1 coordinate: '))
x2 = sympify(input('Enter the x2 coordiante: '))
y2 = sympify(input('Enter the y2 coordinate: '))

m = (y2 - y1)/(x2 - x1)

display((x1, y1))
display((x2, y2))
display(m)
# Out:
# The kernel failed to start due to the missing module 'IPython'. Consider installing this module.
#
# Click <a href='https://aka.ms/kernelFailuresMissingModule'>here</a> for more info.

# %%
# RANDOMIZE

from sympy import sympify, symbols
from random import randint
import sympy as sp

x1, x2, y1, y2 = symbols('x1 x2 y1 y2')

x1 = sympify(randint(-10, 10))
x2 = sympify(randint(-10, 10))
y1 = sympify(randint(-10, 10))

m = (y2 - y1)/(x2 - x1)

display((x1, y1))
display((x2, y2))
display(m)

# %%
# RANDOMIZE 3 OF 4 COORDINATES with SLOPE

from sympy import sympify, symbols
from random import randint
import sympy as sp

x1, x2, y1, y2 = symbols('x1 x2 y1 y2')

x1 = sympify(randint(-10, 10))
x2 = sympify(randint(-10, 10))
y1 = sympify(randint(-10, 10))

m = sympify(input('What is the slope of the line: '))
a = m*(x2-x1)+y1

display((x1, y1))
display((x2, a))

# %%
#

from sympy import sympify, symbols
from random import randint
import sympy as sp

x1, x2, y1, y2 = symbols('x1 x2 y1 y2')

x1 = sympify(input('Type the x1 coordinate: '))
y1 = sympify(input('Type the y1 coordinate: '))
x2 = sympify(input('Type the x2 coordinate: '))

m = sympify(input('What is the slope of the line: '))
a = m*(x2-x1)+y1

display((x1, y1))
display((x2, a))

# %%
from sympy import sympify, symbols
from random import randint
import sympy as sp

x1, x2, y1, y2 = symbols('x1 x2 y1 y2')

x1 = sympify(randint(-10, 10))
y1 = sympify(randint(-10, 10))
y2 = sympify(randint(-10, 10))

m = sympify(input('What is the slope of the line: '))
a = (y2-y1+m*x1)/m

display((x1, y1))
display((a, y2))

# %%
from sympy import sympify, symbols
from random import randint
import sympy as sp

x1, x2, y1, y2 = symbols('x1 x2 y1 y2')

x1 = sympify(input('Type the x1 coordinate: '))
y1 = sympify(input('Type the y1 coordinate: '))
y2 = sympify(input('Type the y2 coordinate: '))

m = sympify(input('What is the slope of the line: '))
a = (y2-y1+m*x1)/m

display((x1, y1))
display((a, y2))
a

# %%
# Factoring Quadratics

from sympy import sympify, symbols, Symbol, factor, Eq
from random import randint

x, a, b, c = symbols('x a b c')

a = sympify(input('Enter the coefficient for x-squared term: '))
b = sympify(input('Enter the coefficient for x term: '))
c = sympify(input('Enter the coefficient for the constant term: '))

quad = a*x**2 + b*x + c

factored_quad = factor(quad)

display(Eq(quad, factored_quad))

# %%
# Find the equation of a line given two points (INPUT)

from sympy import symbols, sympify, Eq, factor
import sympy as sp

x, y, x1, x2, y1, y2, m = symbols('x y x1 x2 y1 y2 m')

x1 = sympify(input('Enter the x1 coordinate: '))
y1 = sympify(input('Enter the y1 coordinate: '))
x2 = sympify(input('Enter the x2 coordiante: '))
y2 = sympify(input('Enter the y2 coordinate: '))

m = (y2 - y1)/(x2 - x1)

line = m*x - m*x1 + y1

# point-slope form
left = y - y1
right = m*(x-x1)

# slope-intercept form
line = m*x - m*x1 + y1

# y-intercept
b = -m*x1 + y1

# x-intercept
x_int = -b/m

print('This is the point-slope form of the line: ')
display(Eq(left, factor(right)))

print('The slope-intercept form of the line: ')
display(Eq(y, line))

print('The x-intercept of the line is: ')
display((x_int, 0))

print('The y-intercept of the line is: ')
display((0, b))

# %%
# Find the equation of a line given two points (RANDOMIZED)

from sympy import symbols, sympify, Eq
import sympy as sp

from random import randint

x, y, x1, x2, y1, y2, m = symbols('x y x1 x2 y1 y2 m')

x1 = sympify(randint(-10, 10))
y1 = sympify(randint(-10, 10))
x2 = sympify(randint(-10, 10))
y2 = sympify(randint(-10, 10))

if x1 != x2:
    m = (y2 - y1)/(x2 - x1)
    line = m*x - m*x1 + y1

    print('The first set of coordinates: ')
    display((x1, y1))
    print('The second set of coordinates: ')
    display((x2, y2))
    print('The slope-intercept form of the line: ')
    display(Eq(y, line))
else:
    while x1 == x2:
        x1 = sympify(randint(-10, 10))
        x2 = sympify(randint(-10, 10))
    m = (y2 - y1)/(x2 - x1)
    line = m*x - m*x1 + y1

    print('The first set of coordinates: ')
    display((x1, y1))
    print('The second set of coordinates: ')
    display((x2, y2))
    print('The slope-intercept form of the line: ')
    display(Eq(y, line))

# %%
# Find the equation of a line given two points (RANDOMIZED, n times)

from sympy import symbols, sympify, Eq
from sympy import symbols, sympify, Eq, factor
import sympy as sp

from random import randint

x, y, x1, x2, y1, y2, m = symbols('x y x1 x2 y1 y2 m')

# Find the equation of a line given two points (RANDOMIZED)


x, y, x1, x2, y1, y2, m = symbols('x y x1 x2 y1 y2 m')

num = int(input('How many problems of these do you want? '))

for i in range(num):

    x1 = sympify(randint(-10, 10))
    y1 = sympify(randint(-10, 10))
    x2 = sympify(randint(-10, 10))
    y2 = sympify(randint(-10, 10))

    if x1 != x2:
        m = (y2 - y1)/(x2 - x1)
        line = m*x - m*x1 + y1

        # point-slope form
        left = y - y1
        right = m*(x-x1)

        print(f'Exercise #{i+1}:')
        print('The first set of coordinates: ')
        display((x1, y1))
        print('The second set of coordinates: ')
        display((x2, y2))
        print('This is the point-slope form of the line: ')
        display(Eq(left, factor(right)))
        print('The slope-intercept form of the line: ')
        display(Eq(y, line))
        print('\n')
    else:
        while x1 == x2:
            x1 = sympify(randint(-10, 10))
            x2 = sympify(randint(-10, 10))
        m = (y2 - y1)/(x2 - x1)
        line = m*x - m*x1 + y1

        # point-slope form
        left = y - y1
        right = m*(x-x1)

        print(f'Exercise #{i+1}:')
        print('The first set of coordinates: ')
        display((x1, y1))
        print('The second set of coordinates: ')
        display((x2, y2))
        print('This is the point-slope form of the line: ')
        display(Eq(left, factor(right)))
        print('The slope-intercept form of the line: ')
        display(Eq(y, line))
        print('\n')

# %%
'''
Find the point-slope and slope-intercept form given a point and the 
slope of a standard form of a line. (INPUT)
'''

from sympy import symbols, sympify, Eq

a, b, x, y, x1, y1 = symbols('a b x y x1 y1')

a = sympify(input('Enter the coefficient of x: '))
b = sympify(input('Enter the coefficient of y: '))
x1 = sympify(input('Enter the x-coordinate: '))
y1 = sympify(input('Enter the y-coordinate: '))

# slope
m = -a/b

# point-slope form
left = y - y1
right = m*(x-x1)

# slope-intercept form
line = m*x - m*x1 + y1

print('This is the point-slope form of the line: ')
display(Eq(left, right))

print('This is the slope-intercept form of the line: ')
display(Eq(y, line))

# %%
'''
Find the point-slope and slope-intercept form given a point and the 
slope of a standard form of a line. (RANDOMIZE)
'''

from sympy import symbols, sympify, Eq, factor
from random import randint

a, b, x, y, x1, y1 = symbols('a b x y x1 y1')

a = sympify(randint(1, 10))
b = sympify(randint(-10, 10))
x1 = sympify(randint(-10, 10))
y1 = sympify(randint(-10, 10))

# slope
m = -b/a

# point-slope form
left = y - y1
right = m*(x-x1)

# slope-intercept form
line = m*x - m*x1 + y1

print('The coefficients of the standard form of a line are: ')
display((a, b))

print('The coordinates are: ')
display((x1, y1))

print('The slope is: ')
display(m)

print('This is the point-slope form of the line: ')
display(Eq(left, factor(right)))
print('This is the slope-intercept form of the line: ')
display(Eq(y, line))

# %%
'''
Find the point-slope and slope-intercept form PERPENDICULAR given a point and the 
slope of a standard form of a line. (RANDOMIZE)
'''

from sympy import symbols, sympify, Eq
from random import randint

a, b, x, y, x1, y1 = symbols('a b x y x1 y1')

a = sympify(randint(1, 10))
b = sympify(randint(-10, 10))
x1 = sympify(randint(-10, 10))
y1 = sympify(randint(-10, 10))

# slope
m = -b/a

# Perpendicular slope
m_perp = 1/m

# point-slope form
left = y - y1
right = (m_perp)*(x-x1)

# slope-intercept form
line = (m_perp)*x - (m_perp)*x1 + y1

print('The coefficients of the standard form of a line are: ')
display((a, b))

print('The coordinates are: ')
display((x1, y1))

print('The slope is: ')
display(m)

print('The negative reciprocal slope is: ')
display(m_perp)

print('This is the point-slope form of the line: ')
display(Eq(left, right))

print('This is the slope-intercept form of the line: ')
display(Eq(y, line))

# %%
'''
Find the point-slope and slope-intercept form given a point and the 
slope of a line in slope-intercept. (INPUT)
'''

from sympy import symbols, sympify, Eq
from random import randint

m, x, y, x1, y1 = symbols('m x y x1 y1')

# input slope
m = sympify(input('Enter the slope of the line: '))

# input the x,y coordinates
x1 = sympify(input('Enter the x-coordinate of the point: '))
y1 = sympify(input('Enter the y-coordinate of the point: '))


# point-slope form
left = y - y1
right = m*(x-x1)

# slope-intercept form
line = m*x - m*x1 + y1

# y-intercept
b = -m*x1 + y1

# x-intercept
x_int = -b/m

print('This is the point-slope form of the line: ')
display(Eq(left, right))

print('This is the slope-intercept form of the line: ')
display(Eq(y, line))

print('The x-intercept of the line is: ')
display((x_int, 0))

print('The y-intercept of the line is: ')
display((0, b))

# %%
'''
Find the point-slope and slope-intercept form given a point and the 
slope of a line in slope-intercept. (RANDOMIZE)
'''

from sympy import symbols, sympify, Eq, factor
from random import randint

a, b, x, y, x1, y1 = symbols('a b x y x1 y1')

# randomize slope
a = sympify(randint(-10, 10))
b = sympify(randint(1, 10))
m = a/b

# randomize the x,y coordinates
x1 = sympify(randint(-10, 10))
y1 = sympify(randint(-10, 10))


# point-slope form
left = y - y1
right = m*(x-x1)

# slope-intercept form
line = m*x - m*x1 + y1

# y-intercept
b = -m*x1 + y1

# x-intercept
x_int = -b/m

print('The coordinates are: ')
display((x1, y1))

print('The slope is: ')
display(m)

print('This is the point-slope form of the line: ')
display(Eq(left, factor(right)))

print('This is the slope-intercept form of the line: ')
display(Eq(y, line))

print('The x-intercept of the line is: ')
display((x_int, 0))

print('The y-intercept of the line is: ')
display((0, b))

# %%
'''
Find the point-slope and slope-intercept form given a point and the 
slope of a line in slope-intercept. (RANDOMIZE, n times)
'''

from sympy import symbols, sympify, Eq, factor
from random import randint

a, b, x, y, x1, y1 = symbols('a b x y x1 y1')

num = int(input('How many problems of these do you want? '))

for i in range(num):

    # randomize slope
    a = sympify(randint(-10, 10))
    b = sympify(randint(1, 10))
    m = a/b

    # randomize the x,y coordinates
    x1 = sympify(randint(-10, 10))
    y1 = sympify(randint(-10, 10))

    # point-slope form
    left = y - y1
    right = m*(x-x1)

    # slope-intercept form
    line = m*x - m*x1 + y1

    print(f'Problem #{i+1}')
    print('The coordinates are: ')
    display((x1, y1))

    print('The slope is: ')
    display(m)

    print('This is the point-slope form of the line: ')
    display(Eq(left, factor(right)))

    print('This is the slope-intercept form of the line: ')
    display(Eq(y, line))
    print('\n')

# %%
'''
Find the point-slope and slope-intercept form of a 
PARALLEL line given a point and a line. (INPUT)
'''

from sympy import symbols, sympify, Eq
from random import randint

m, x, y, x1, y1 = symbols('m x y x1 y1')

# input slope
m = sympify(input('Enter the slope of the line: '))

# input the x,y coordinates
x1 = sympify(input('Enter the x-coordinate of the point: '))
y1 = sympify(input('Enter the y-coordinate of the point: '))

# point-slope form
left = y - y1
right = m*(x-x1)

# slope-intercept form
line = m*x - m*x1 + y1

# y-intercept
b = -m*x1 + y1

# x-intercept
x_int = -b/m

print('This is the point-slope form of the line: ')
display(Eq(left, right))

print('This is the slope-intercept form of the line: ')
display(Eq(y, line))

print('The x-intercept of the line is: ')
display((x_int, 0))

print('The y-intercept of the line is: ')
display((0, b))

# %%
'''
Find the point-slope and slope-intercept form of a 
PERPENDICULAR line given a point and a line. (INPUT)
'''

from sympy import symbols, sympify, Eq
from random import randint

m, x, y, x1, y1 = symbols('m x y x1 y1')

# input slope
m = sympify(input('Enter the slope of the line: '))

# input the x,y coordinates
x1 = sympify(input('Enter the x-coordinate of the point: '))
y1 = sympify(input('Enter the y-coordinate of the point: '))

# new negative reciprocal slope
m_perp = (-1/m)

# point-slope form
left = y - y1
right = (m_perp)*(x-x1)

# slope-intercept form
line = (m_perp)*x - (m_perp)*x1 + y1

print('This is the point-slope form of the line: ')
display(Eq(left, right))

print('This is the slope-intercept form of the line: ')
display(Eq(y, line))

# %%
'''
Find the point-slope and slope-intercept form of a 
PERPENDICULAR line given a point and a line. (RANDOMIZED)
'''

from sympy import symbols, sympify, Eq
from random import randint

m, x, y, x1, y1 = symbols('m x y x1 y1')

# randomize slope
a = sympify(randint(-10, 10))
b = sympify(randint(1, 10))
m = a/b

# randomize the x,y coordinates
x1 = sympify(randint(-10, 10))
y1 = sympify(randint(-10, 10))

# new negative reciprocal slope
m_perp = (-1/m)

# point-slope form
left = y - y1
right = (m_perp)*(x-x1)

# slope-intercept form
line = (m_perp)*x - (m_perp)*x1 + y1

print('The coordinates are: ')
display((x1, y1))

print('The slope is: ')
display(m)

print('The negative reciprocal slope is: ')
display(m_perp)

print('This is the point-slope form of the line: ')
display(Eq(left, right))

print('This is the slope-intercept form of the line: ')
display(Eq(y, line))

# %%
# Find the equation of a line PERPENDICULAR to a line going through two points (RANDOMIZED)

from sympy import symbols, sympify, Eq
import sympy as sp

from random import randint

x0, y0, x, y, x1, x2, y1, y2, m = symbols('x0 y0 x y x1 x2 y1 y2 m')

x0 = sympify(randint(-10, 10))
y0 = sympify(randint(-10, 10))

x1 = sympify(randint(-10, 10))
y1 = sympify(randint(-10, 10))
x2 = sympify(randint(-10, 10))
y2 = sympify(randint(-10, 10))

if x1 != x2:
    m = -1*(x2 - x1)/(y2 - y1)
    line = m*x - m*x0 + y0

    print('The first set of coordinates: ')
    display((x1, y1))
    print('The second set of coordinates: ')
    display((x2, y2))
    print('The coordinates of the point that the perpendicular line goes through: ')
    display((x0, y0))
    print('The slope-intercept form of the line: ')
    display(Eq(y, line))
else:
    while x1 == x2:
        x1 = sympify(randint(-10, 10))
        x2 = sympify(randint(-10, 10))
    m = (y2 - y1)/(x2 - x1)
    line = m*x - m*x0 + y0

    print('The first set of coordinates: ')
    display((x1, y1))
    print('The second set of coordinates: ')
    display((x2, y2))

    print('The coordinates of the point that the perpendicular line goes through: ')
    display((x0, y0))

    print('The slope-intercept form of the perpendicular line: ')
    display(Eq(y, line))

# %%
# Find the equation of a line PERPENDICULAR to a line going through two points (INPUT)

from sympy import symbols, sympify, Eq
import sympy as sp

from random import randint

x0, y0, x, y, x1, x2, y1, y2, m = symbols('x0 y0 x y x1 x2 y1 y2 m')

x0 = sympify(input(
    'Input the x-coordinate of the point the perpendicular line goes through: '))
y0 = sympify(input(
    'Input the y-coordinate of the point the perpendicular line goes through: '))

x1 = sympify(input('Input the x1 coordinate: '))
y1 = sympify(input('Input the y1 coordinate: '))
x2 = sympify(input('Input the x2 coordinate: '))
y2 = sympify(input('Input the y2 coordinate: '))

if x1 != x2:
    m = -1*(x2 - x1)/(y2 - y1)
    line = m*x - m*x0 + y0

    print('The first set of coordinates: ')
    display((x1, y1))
    print('The second set of coordinates: ')
    display((x2, y2))
    print('The coordinates of the point that the perpendicular line goes through: ')
    display((x0, y0))
    print('The slope-intercept form of the line: ')
    display(Eq(y, line))
else:
    while x1 == x2:
        x1 = sympify(randint(-10, 10))
        x2 = sympify(randint(-10, 10))
    m = (y2 - y1)/(x2 - x1)
    line = m*x - m*x0 + y0

    print('The first set of coordinates: ')
    display((x1, y1))
    print('The second set of coordinates: ')
    display((x2, y2))

    print('The coordinates of the point that the perpendicular line goes through: ')
    display((x0, y0))

    print('The slope-intercept form of the perpendicular line: ')
    display(Eq(y, line))
